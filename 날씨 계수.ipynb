# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime 
from datetime import timedelta

# %%
import math
from datetime import date
import datetime as dt

# %%
pd.set_option('display.max_columns', None)

# %%
datatime = pd.read_csv("C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/01_제공데이터/data_minute_stamp_3.csv",encoding='euc-kr')
display(datatime.head(), datatime.shape)
# Out:
#             방송일시  노출            상품명  week_number  minute_stamp  saled    마더코드  \
# 0  2019.1.1 6:00  20  테이트 남성 셀린니트3종            1           180   26.0  100346
# 1  2019.1.1 6:00  20  테이트 남성 셀린니트3종            1           181   26.0  100346
# 2  2019.1.1 6:20  20  테이트 남성 셀린니트3종            1           182   41.0  100346
# 3  2019.1.1 6:20  20  테이트 남성 셀린니트3종            1           183   41.0  100346
# 4  2019.1.1 6:40  20  테이트 남성 셀린니트3종            1           184   84.0  100346
#
#      상품코드   판매단가 상품군  세부상품군
# 0  201072  39900  의류  남성상의1
# 1  201072  39900  의류  남성상의1
# 2  201072  39900  의류  남성상의1
# 3  201072  39900  의류  남성상의1
# 4  201072  39900  의류  남성상의1
# (78026, 11)

# %%
testtime = pd.read_csv("C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/01_제공데이터/data_stamps_test.csv",encoding='euc-kr')
display(testtime.head(), testtime.shape)
# Out:
#    Unnamed: 0  Unnamed: 0.1                 방송일시  노출              상품명  \
# 0           0             0  2020-06-01 06:20:00  20  잭필드 남성  반팔셔츠 4종
# 1           1             1  2020-06-01 06:20:00  20  잭필드 남성  반팔셔츠 4종
# 2           2             0  2020-06-01 06:40:00  20  잭필드 남성  반팔셔츠 4종
# 3           3             1  2020-06-01 06:40:00  20  잭필드 남성  반팔셔츠 4종
# 4           4             0  2020-06-01 07:00:00  20  잭필드 남성  반팔셔츠 4종
#
#    week_number  minute_stamp   판매단가 상품군  weekend_stamp  holiday_stamp
# 0           23            38  29900  의류              0              0
# 1           23            39  29900  의류              0              0
# 2           23            40  29900  의류              0              0
# 3           23            41  29900  의류              0              0
# 4           23            42  29900  의류              0              0
# (5867, 11)

# %%
display(testtime.columns, datatime.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', '방송일시', '노출', '상품명', 'week_number',
#        'minute_stamp', '판매단가', '상품군', 'weekend_stamp', 'holiday_stamp'],
#       dtype='object')
# Index(['방송일시', '노출', '상품명', 'week_number', 'minute_stamp', 'saled', '마더코드',
#        '상품코드', '판매단가', '상품군', '세부상품군'],
#       dtype='object')

# %%
datatime['방송일시'] = pd.to_datetime(datatime['방송일시'])

# %%
datatime['date'] = datatime['방송일시'].dt.date
datatime['time'] = datatime['방송일시'].dt.time
datatime['weekday'] = datatime['방송일시'].dt.weekday

# %%
datatime['date'] = pd.to_datetime(datatime['date'])

# %%
datatime.head()
# Out:
#                  방송일시  노출            상품명  week_number  minute_stamp  saled  \
# 0 2019-01-01 06:00:00  20  테이트 남성 셀린니트3종            1           180   26.0
# 1 2019-01-01 06:00:00  20  테이트 남성 셀린니트3종            1           181   26.0
# 2 2019-01-01 06:20:00  20  테이트 남성 셀린니트3종            1           182   41.0
# 3 2019-01-01 06:20:00  20  테이트 남성 셀린니트3종            1           183   41.0
# 4 2019-01-01 06:40:00  20  테이트 남성 셀린니트3종            1           184   84.0
#
#      마더코드    상품코드   판매단가 상품군  세부상품군       date      time  weekday
# 0  100346  201072  39900  의류  남성상의1 2019-01-01  06:00:00        1
# 1  100346  201072  39900  의류  남성상의1 2019-01-01  06:00:00        1
# 2  100346  201072  39900  의류  남성상의1 2019-01-01  06:20:00        1
# 3  100346  201072  39900  의류  남성상의1 2019-01-01  06:20:00        1
# 4  100346  201072  39900  의류  남성상의1 2019-01-01  06:40:00        1

# %%
datatime.dtypes
# Out:
# 방송일시            datetime64[ns]
# 노출                       int64
# 상품명                     object
# week_number              int64
# minute_stamp             int64
# saled                  float64
# 마더코드                     int64
# 상품코드                     int64
# 판매단가                     int64
# 상품군                     object
# 세부상품군                   object
# date            datetime64[ns]
# time                    object
# weekday                  int64
# dtype: object

# %%
testtime['방송일시'] = pd.to_datetime(testtime['방송일시'])

testtime['date'] = testtime['방송일시'].dt.date
testtime['time'] = testtime['방송일시'].dt.time
testtime['weekday'] = testtime['방송일시'].dt.weekday

# %%
testtime['date'] = pd.to_datetime(testtime['date'])

# %%
display(datatime, testtime)
# Out:
#                      방송일시  노출                       상품명  week_number  \
# 0     2019-01-01 06:00:00  20             테이트 남성 셀린니트3종            1
# 1     2019-01-01 06:00:00  20             테이트 남성 셀린니트3종            1
# 2     2019-01-01 06:20:00  20             테이트 남성 셀린니트3종            1
# 3     2019-01-01 06:20:00  20             테이트 남성 셀린니트3종            1
# 4     2019-01-01 06:40:00  20             테이트 남성 셀린니트3종            1
# ...                   ...  ..                       ...          ...
# 78021 2020-01-01 00:40:00  20  삼성화재 행복한파트너 주택화재보험(1912)            1
# 78022 2020-01-01 01:00:00  20  삼성화재 행복한파트너 주택화재보험(1912)            1
# 78023 2020-01-01 01:20:00  20        더케이 예다함 상조서비스(티포트)            1
# 78024 2020-01-01 01:20:00  20        더케이 예다함 상조서비스(티포트)            1
# 78025 2020-01-01 01:40:00  17        더케이 예다함 상조서비스(티포트)            1
#
#        minute_stamp  saled    마더코드    상품코드   판매단가 상품군  세부상품군       date  \
# ...

# %%
# result = pd.merge(user_usage,
#                  user_device[['use_id', 'platform', 'device']],
#                  on='use_id', 
#                  how='left')

# %%
display(datatime.shape, testtime.shape)
# Out:
# (78026, 14)
# (5867, 14)

# %%
# wthr.columns

# %% [markdown]
# # 지역묶기

# %%
wthr19 = pd.read_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/19wthr.csv', encoding = 'euc-kr')
wthr20 = pd.read_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/20wthr.csv', encoding = 'euc-kr')
wthr20_7 = pd.read_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/20_7wthr.csv', encoding = 'euc-kr')

# %%
wthr19['일시'] = pd.to_datetime(wthr19['일시'])
wthr20['일시'] = pd.to_datetime(wthr20['일시'])
wthr20_7['일시'] = pd.to_datetime(wthr20_7['일시'])

# %%
wthr19 =wthr19.fillna(0)
wthr20 =wthr20.fillna(0)
wthr20_7 =wthr20_7.fillna(0)

# %%
pd.DataFrame(wthr20_7['지점'].unique())
# Out:
#       0
# 0    90
# 1    93
# 2    95
# 3    98
# 4    99
# ..  ...
# 90  285
# 91  288
# 92  289
# 93  294
# 94  295
#
# [95 rows x 1 columns]

# %%
wthr19['지역'] = np.NAN
wthr20['지역'] = np.NAN
wthr20_7['지역'] = np.NAN

# %%
g1 = [116, 108, 201, 102, 112, 98,119,202,203,99 ]
g2 = [159,152,294,284,253,295,288,255,289,257,263,192,155,162,264,285]
g3 = [143,176,283,279,273,271,137,136,277,272,281,115,130,278,276,138]
g4 = [156,259,262,266,165,164,258,174,168,252,170,260,256,175,268,261,169]
g5 = [172,251,140,247,243,254,244,248,146,245]
g6 = [133,238,235,236,129,232,177,239]
g7 = [226,221,131,135,127]
g8 = [105,100,106,104,93,214,90,121,114,211,217,95,101,216,212]
g9 =[185,189,187,188,265,184]

# %%
display(wthr19.shape, wthr20.shape, wthr20_7.shape)
# Out:
# (34831, 9)
# (2850, 9)
# (95, 8)

# %%
for i in  range(34831) :
    if wthr19['지점'][i] in g1:
        wthr19['지역'][i] = 1
    elif wthr19['지점'][i] in g2:
         wthr19['지역'][i] = 2
    elif wthr19['지점'][i] in g3:
         wthr19['지역'][i] = 3
    elif wthr19['지점'][i] in g4:
         wthr19['지역'][i] = 4            
    elif wthr19['지점'][i] in g5:
         wthr19['지역'][i] = 5            
    elif wthr19['지점'][i] in g6:
         wthr19['지역'][i] = 6           
    elif wthr19['지점'][i] in g7:
         wthr19['지역'][i] = 7            
    elif wthr19['지점'][i] in g8:
         wthr19['지역'][i] = 8  
    elif wthr19['지점'][i] in g9:
         wthr19['지역'][i] = 9
    else:
        print(i)
# Out:
# <ipython-input-26-d2192d0561b6>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr19['지역'][i] = 8
# <ipython-input-26-d2192d0561b6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr19['지역'][i] = 1
# <ipython-input-26-d2192d0561b6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr19['지역'][i] = 3
# <ipython-input-26-d2192d0561b6>:15: SettingWithCopyWarning:
# ...

# %%
for i in  range(2850) :
    if wthr20['지점'][i] in g1:
        wthr20['지역'][i] = 1
    elif wthr20['지점'][i] in g2:
         wthr20['지역'][i] = 2
    elif wthr20['지점'][i] in g3:
         wthr20['지역'][i] = 3
    elif wthr20['지점'][i] in g4:
         wthr20['지역'][i] = 4            
    elif wthr20['지점'][i] in g5:
         wthr20['지역'][i] = 5            
    elif wthr20['지점'][i] in g6:
         wthr20['지역'][i] = 6           
    elif wthr20['지점'][i] in g7:
         wthr20['지역'][i] = 7            
    elif wthr20['지점'][i] in g8:
         wthr20['지역'][i] = 8  
    elif wthr20['지점'][i] in g9:
         wthr20['지역'][i] = 9
    else:
        print(i)
# Out:
# <ipython-input-27-1d99d064a8bf>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr20['지역'][i] = 8
# <ipython-input-27-1d99d064a8bf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr20['지역'][i] = 1
# <ipython-input-27-1d99d064a8bf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr20['지역'][i] = 3
# <ipython-input-27-1d99d064a8bf>:15: SettingWithCopyWarning:
# ...

# %%
for i in  range(95) :
    if wthr20_7['지점'][i] in g1:
        wthr20_7['지역'][i] = 1
    elif wthr20_7['지점'][i] in g2:
         wthr20_7['지역'][i] = 2
    elif wthr20_7['지점'][i] in g3:
         wthr20_7['지역'][i] = 3
    elif wthr20_7['지점'][i] in g4:
         wthr20_7['지역'][i] = 4            
    elif wthr20_7['지점'][i] in g5:
         wthr20_7['지역'][i] = 5            
    elif wthr20_7['지점'][i] in g6:
         wthr20_7['지역'][i] = 6           
    elif wthr20_7['지점'][i] in g7:
         wthr20_7['지역'][i] = 7            
    elif wthr20_7['지점'][i] in g8:
         wthr20_7['지역'][i] = 8  
    elif wthr20_7['지점'][i] in g9:
         wthr20_7['지역'][i] = 9
    else:
        print(i)
# Out:
# <ipython-input-28-5436f2db05bc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr20_7['지역'][i] = 8
# <ipython-input-28-5436f2db05bc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr20_7['지역'][i] = 1
# <ipython-input-28-5436f2db05bc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wthr20_7['지역'][i] = 3
# <ipython-input-28-5436f2db05bc>:15: SettingWithCopyWarning:
# ...

# %%
#pd.DataFrame(wthr19['지역'].unique())

# %%
#pd.DataFrame(wthr20['지역'].unique())

# %%
wthr19 =wthr19.drop(['지점', '지점명'], axis = 1)

# %%
wthr19_m = wthr19.groupby(['일시', '지역']).mean().reset_index()
wthr19_m
# Out:
#              일시   지역  평균기온(°C)  일강수량(mm)  최대 풍속(m/s)  평균 상대습도(%)  일 최심신적설(cm)
# 0    2019-01-01  1.0 -5.466667  0.000000    5.533333   57.944444     0.000000
# 1    2019-01-01  2.0 -0.068750  0.000000    5.656250   50.606250     0.000000
# 2    2019-01-01  3.0 -1.993333  0.000000    6.313333   50.666667     0.000000
# 3    2019-01-01  4.0  0.926667  0.026667    7.566667   63.880000     0.000000
# 4    2019-01-01  5.0 -1.480000  0.380000    4.870000   73.570000     0.010000
# ...         ...  ...       ...       ...         ...         ...          ...
# 3289 2020-01-01  5.0 -1.650000  0.000000    3.680000   70.490000     0.000000
# 3290 2020-01-01  6.0 -1.262500  0.025000    3.000000   72.387500     0.000000
# 3291 2020-01-01  7.0 -2.680000  0.040000    3.200000   70.200000     0.000000
# 3292 2020-01-01  8.0 -2.792857  0.007143    4.728571   62.792857     0.021429
# 3293 2020-01-01  9.0  5.375000  0.000000    5.675000   67.400000     0.000000
#
# [3294 rows x 7 columns]

# %%
wthr20 =wthr20.drop(['지점', '지점명'], axis = 1)

# %%
wthr20_m = wthr20.groupby(['일시', '지역']).mean().reset_index()
wthr20_m
# Out:
#             일시   지역   평균기온(°C)   일강수량(mm)  최대 풍속(m/s)  평균 상대습도(%)  일 최심신적설(cm)
# 0   2020-06-01  1.0  19.111111   0.322222    6.400000   69.088889          0.0
# 1   2020-06-01  2.0  22.431250   0.018750    5.031250   60.431250          0.0
# 2   2020-06-01  3.0  21.926667   0.013333    6.400000   52.593333          0.0
# 3   2020-06-01  4.0  20.185714   0.021429    5.171429   72.550000          0.0
# 4   2020-06-01  5.0  19.030000   0.440000    5.250000   74.270000          0.0
# ..         ...  ...        ...        ...         ...         ...          ...
# 265 2020-06-30  5.0  19.720000   7.000000    6.930000   92.370000          0.0
# 266 2020-06-30  6.0  19.812500  24.737500    4.937500   93.212500          0.0
# 267 2020-06-30  7.0  20.020000  20.600000    5.800000   88.100000          0.0
# 268 2020-06-30  8.0  19.121429  79.807143    6.900000   87.485714          0.0
# 269 2020-06-30  9.0  21.925000   0.000000   11.975000   83.375000          0.0
#
# [270 rows x 7 columns]

# %%
wthr20_7 =wthr20_7.drop(['지점', '지점명'], axis = 1)

# %%
wthr20_7_m = wthr20_7.groupby(['일시', '지역']).mean().reset_index()
wthr20_7_m
# Out:
#           일시   지역   평균기온(°C)  일강수량(mm)  최대 풍속(m/s)  평균 상대습도(%)
# 0 2020-07-01  1.0  20.300000  0.488889    3.400000   87.566667
# 1 2020-07-01  2.0  21.925000  0.100000    3.912500   75.762500
# 2 2020-07-01  3.0  19.840000  4.980000    5.066667   83.993333
# 3 2020-07-01  4.0  20.521429  0.014286    5.214286   74.442857
# 4 2020-07-01  5.0  20.790000  0.150000    3.950000   78.750000
# 5 2020-07-01  6.0  20.637500  0.662500    3.587500   84.150000
# 6 2020-07-01  7.0  19.640000  3.040000    3.120000   82.320000
# 7 2020-07-01  8.0  18.721429  3.107143    3.500000   84.900000
# 8 2020-07-01  9.0  22.025000  0.000000    5.900000   76.700000

# %%
wthr19_m =wthr19_m.drop(['일 최심신적설(cm)'] , axis = 1)
wthr20_m = wthr20_m.drop(['일 최심신적설(cm)'] , axis = 1)

# %%
display(wthr20_7_m.head(10), wthr19_m.head(10), wthr20_m.head(10))
# Out:
#           일시   지역   평균기온(°C)  일강수량(mm)  최대 풍속(m/s)  평균 상대습도(%)
# 0 2020-07-01  1.0  20.300000  0.488889    3.400000   87.566667
# 1 2020-07-01  2.0  21.925000  0.100000    3.912500   75.762500
# 2 2020-07-01  3.0  19.840000  4.980000    5.066667   83.993333
# 3 2020-07-01  4.0  20.521429  0.014286    5.214286   74.442857
# 4 2020-07-01  5.0  20.790000  0.150000    3.950000   78.750000
# 5 2020-07-01  6.0  20.637500  0.662500    3.587500   84.150000
# 6 2020-07-01  7.0  19.640000  3.040000    3.120000   82.320000
# 7 2020-07-01  8.0  18.721429  3.107143    3.500000   84.900000
# 8 2020-07-01  9.0  22.025000  0.000000    5.900000   76.700000
#           일시   지역  평균기온(°C)  일강수량(mm)  최대 풍속(m/s)  평균 상대습도(%)
# 0 2019-01-01  1.0 -5.466667  0.000000    5.533333   57.944444
# 1 2019-01-01  2.0 -0.068750  0.000000    5.656250   50.606250
# 2 2019-01-01  3.0 -1.993333  0.000000    6.313333   50.666667
# 3 2019-01-01  4.0  0.926667  0.026667    7.566667   63.880000
# ...

# %%
wthr20_m = pd.concat([wthr20_m, wthr20_7_m])

# %%
wthr20_m.head()
# Out:
#           일시   지역   평균기온(°C)  일강수량(mm)  최대 풍속(m/s)  평균 상대습도(%)
# 0 2020-06-01  1.0  19.111111  0.322222    6.400000   69.088889
# 1 2020-06-01  2.0  22.431250  0.018750    5.031250   60.431250
# 2 2020-06-01  3.0  21.926667  0.013333    6.400000   52.593333
# 3 2020-06-01  4.0  20.185714  0.021429    5.171429   72.550000
# 4 2020-06-01  5.0  19.030000  0.440000    5.250000   74.270000

# %%
wthr19_m.to_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/wthr19_m.csv')

# %%
wthr20_m.to_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/wthr20_m.csv')

# %%
wthr20_m.dtypes
# Out:
# 일시            datetime64[ns]
# 지역                   float64
# 평균기온(°C)             float64
# 일강수량(mm)             float64
# 최대 풍속(m/s)           float64
# 평균 상대습도(%)           float64
# dtype: object

# %%
wthr19_m.dtypes
# Out:
# 일시            datetime64[ns]
# 지역                   float64
# 평균기온(°C)             float64
# 일강수량(mm)             float64
# 최대 풍속(m/s)           float64
# 평균 상대습도(%)           float64
# dtype: object

# %%
wthr20_m.tail()
# Out:
#           일시   지역   평균기온(°C)  일강수량(mm)  최대 풍속(m/s)  평균 상대습도(%)
# 4 2020-07-01  5.0  20.790000  0.150000      3.9500       78.75
# 5 2020-07-01  6.0  20.637500  0.662500      3.5875       84.15
# 6 2020-07-01  7.0  19.640000  3.040000      3.1200       82.32
# 7 2020-07-01  8.0  18.721429  3.107143      3.5000       84.90
# 8 2020-07-01  9.0  22.025000  0.000000      5.9000       76.70

# %% [markdown]
# # 기존 데이터 프레임에 추가

# %%
display(datatime.head(), wthr19_m.head(), testtime.head(), wthr20_m.head())
# Out:
#                  방송일시  노출            상품명  week_number  minute_stamp  saled  \
# 0 2019-01-01 06:00:00  20  테이트 남성 셀린니트3종            1           180   26.0
# 1 2019-01-01 06:00:00  20  테이트 남성 셀린니트3종            1           181   26.0
# 2 2019-01-01 06:20:00  20  테이트 남성 셀린니트3종            1           182   41.0
# 3 2019-01-01 06:20:00  20  테이트 남성 셀린니트3종            1           183   41.0
# 4 2019-01-01 06:40:00  20  테이트 남성 셀린니트3종            1           184   84.0
#
#      마더코드    상품코드   판매단가 상품군  세부상품군       date      time  weekday
# 0  100346  201072  39900  의류  남성상의1 2019-01-01  06:00:00        1
# 1  100346  201072  39900  의류  남성상의1 2019-01-01  06:00:00        1
# 2  100346  201072  39900  의류  남성상의1 2019-01-01  06:20:00        1
# 3  100346  201072  39900  의류  남성상의1 2019-01-01  06:20:00        1
# 4  100346  201072  39900  의류  남성상의1 2019-01-01  06:40:00        1
#           일시   지역  평균기온(°C)  일강수량(mm)  최대 풍속(m/s)  평균 상대습도(%)  일 최심신적설(cm)
# ...

# %%
datatime_t =  datatime.merge(wthr19_m, left_on = "date", right_on = "일시" , how = 'left' )

# %%
datatime_t.shape
# Out:
# (702234, 20)

# %%
# datatime_t= datatime_t.drop(['일 최심신적설(cm)'], axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-7e5cd9a8fb92> in <module>
# ----> 1 datatime_t= datatime_t.drop(['일 최심신적설(cm)'], axis =1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4155                 weight  1.0     0.8
#    4156         """
# -> 4157         return super().drop(
#    4158             labels=labels,
#    4159             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
testtime_t =  testtime.merge(wthr20_m, left_on = "date", right_on = "일시" , how = 'left' )

# %%
testtime_t.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                방송일시  노출              상품명  \
# 0           0             0 2020-06-01 06:20:00  20  잭필드 남성  반팔셔츠 4종
# 1           0             0 2020-06-01 06:20:00  20  잭필드 남성  반팔셔츠 4종
# 2           0             0 2020-06-01 06:20:00  20  잭필드 남성  반팔셔츠 4종
# 3           0             0 2020-06-01 06:20:00  20  잭필드 남성  반팔셔츠 4종
# 4           0             0 2020-06-01 06:20:00  20  잭필드 남성  반팔셔츠 4종
#
#    week_number  minute_stamp   판매단가 상품군  weekend_stamp  holiday_stamp  \
# 0           23            38  29900  의류              0              0
# 1           23            38  29900  의류              0              0
# 2           23            38  29900  의류              0              0
# 3           23            38  29900  의류              0              0
# 4           23            38  29900  의류              0              0
#
#         date      time  weekday         일시   지역   평균기온(°C)  일강수량(mm)  \
# ...

# %%
# testtime_t =testtime_t.drop(['일 최심신적설(cm)'], axis =1)

# %%
datatime_t.to_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/min_stamp_wth_wthr.csv')

# %%
testtime_t.to_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/test_stamp_wth_wthr.csv')

# %%
display(datatime_t.shape, testtime_t.shape)
# Out:
# (702234, 20)
# (52675, 20)

# %% [markdown]
# ## 날씨 Categorize

# %%
train = pd.read_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/min_stamp_wth_wthr.csv')

# %%
test = pd.read_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/test_stamp_wth_wthr.csv')

# %%
train['c기온'] = ""
train['c강수'] = ""
train['c습도'] = ""
train['c풍속'] = ""

test['c기온'] = ""
test['c강수'] = ""
test['c습도'] = ""
test['c풍속'] = ""

# %%
# for i in range(702234):
#     if (train['평균기온(°C)'][i] <= 6.060000):
#         train['s기온'][i] = 0 
#     elif ((train['평균기온(°C)'][i] > 6.060000) &( train['평균기온(°C)'][i] <= 14.770000)):
#         train['s기온'][i] = 1 
#     elif ((train['평균기온(°C)'][i] > 14.770000) & (train['평균기온(°C)'][i] <= 21.657143)):
#         train['s기온'][i] = 2
#     else:
#         train['s기온'][i] = 3

# %%
train['최대 풍속(m/s)'].describe()
# Out:
# count    702234.000000
# mean          4.723113
# std           1.570776
# min           1.800000
# 25%           3.650000
# 50%           4.400000
# 75%           5.450000
# max          17.350000
# Name: 최대 풍속(m/s), dtype: float64

# %%
train.describe()
# Out:
#           Unnamed: 0             노출    week_number   minute_stamp  \
# count  702234.000000  702234.000000  702234.000000  702234.000000
# mean   351116.500000      20.972996      26.260503     523.191244
# std    202717.638804       4.083661      14.698626     291.758719
# min         0.000000       2.000000       1.000000       0.000000
# 25%    175558.250000      20.000000      14.000000     270.000000
# 50%    351116.500000      20.000000      26.000000     525.000000
# 75%    526674.750000      20.000000      39.000000     784.000000
# max    702233.000000      60.000000      52.000000    1009.000000
#
#                saled           마더코드           상품코드          판매단가  \
# count  696474.000000  702234.000000  702234.000000  7.022340e+05
# mean      145.748068  100393.908966  201225.865058  4.744597e+05
# std       215.641546     252.107807     740.620175  7.445754e+05
# min         0.000000  100000.000000  200000.000000  0.000000e+00
# ...

# %%
test.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            노출   week_number  \
# count  52675.000000  52675.000000    52675.000000  52675.000000  52675.000000
# mean   26337.000000   2930.285999        0.561367     21.116298     24.562354
# std    15206.107052   1692.551669        0.641587      6.056093      1.231292
# min        0.000000      0.000000        0.000000      6.000000     23.000000
# 25%    13168.500000   1463.000000        0.000000     20.000000     23.000000
# 50%    26337.000000   2931.000000        1.000000     20.000000     24.000000
# 75%    39505.500000   4394.000000        1.000000     20.000000     26.000000
# max    52674.000000   5866.000000        5.000000     60.000000     27.000000
#
#        minute_stamp          판매단가  weekend_stamp  holiday_stamp       weekday  \
# count  52675.000000  5.267500e+04   52675.000000   52675.000000  52675.000000
# mean     537.728695  1.986694e+05       0.340009       0.055017      3.134846
# ...

# %%
train.shape
# Out:
# (702234, 21)

# %%
total = pd.concat([train, test])

# %%
total['c기온'] =np.digitize(total['평균기온(°C)'],bins=[-20, 6.060000 ,14.76 , 21.66 , 50])
total['c강수'] =np.digitize(total['일강수량(mm)'],bins=[0, 0.825, 200])
total['c바람'] =np.digitize(total['최대 풍속(m/s)'],bins=[0, 3.65 , 4.4 , 5.45 , 17.35])
total['c습도'] =np.digitize(total['평균 상대습도(%)'],bins=[20,58.937500,70.430000,79.437500,100])

# %%
total.tail()
# Out:
#        Unnamed: 0                 방송일시  노출             상품명  week_number  \
# 52798       52798  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
# 52799       52799  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
# 52800       52800  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
# 52801       52801  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
# 52802       52802  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
#
#        minute_stamp  saled  마더코드  상품코드   판매단가 상품군 세부상품군        date      time  \
# 52798           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
# 52799           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
# 52800           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
# 52801           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
# 52802           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
#
# ...

# %%
train2 = total[:len(train)]
test2 = total[len(train):]

# %%
train2.to_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/train2_0925.csv')
test2.to_csv('C:/Users/jenny/Desktop/빅콘/2020빅콘테스트 문제데이터(데이터분석분야-챔피언리그)/날씨/test2_0925.csv')

# %%
test2.tail()
# Out:
#        Unnamed: 0                 방송일시  노출             상품명  week_number  \
# 52798       52798  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
# 52799       52799  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
# 52800       52800  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
# 52801       52801  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
# 52802       52802  2020-07-01 01:40:00  16  아놀드파마 티셔츠레깅스세트           27
#
#        minute_stamp  saled  마더코드  상품코드   판매단가 상품군 세부상품군        date      time  \
# 52798           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
# 52799           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
# 52800           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
# 52801           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
# 52802           299    NaN   NaN   NaN  69900  의류   NaN  2020-07-01  01:40:00
#
# ...

# %% [markdown]
# ## 폭염 feature col

# %%
pd.DataFrame(pokyum07['지점'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-d9271474246e> in <module>
# ----> 1 pd.DataFrame(pokyum07['지점'].unique())
#
# NameError: name 'pokyum07' is not defined

# %%
# 19년 5월, 6월 폭염일 없음

# %%
frames = [pokyum05, pokyum06, pokyum07, pokyum08, pokyum09]

# %%
# 폭염 5월-9월 데이터 합

# %%
pokyum = pd.concat(frames, axis=0, join='outer', ignore_index=False, keys=None,
          levels=None, names=None, verify_integrity=False, copy=True)
pokyum.head()

# %%
temp = pokyum[pokyum['폭염여부(O/X)'] == 'O' ]
temp.head(300)

# %%
temp.dtypes

# %%
a = pd.DataFrame(temp.groupby(['일시']).agg({'폭염여부(O/X)':'count'})).reset_index()
a = a[a['폭염여부(O/X)'] >= 3]
list_date = a['일시'].unique()

# %%
a['date'] = a['일시']
a = a.drop(['일시'], axis = 1)

# %%
list_date

# %%
datatime = pd.merge(datatime,
                 a[['date', '폭염여부(O/X)' ]],
                 on='date', 
                 how='left')

# %%
datatime.fillna(0)
